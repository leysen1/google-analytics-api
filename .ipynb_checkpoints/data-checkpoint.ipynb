# %% [markdown]
# ## Data Sets

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
plt.style.use('seaborn')

# %% [markdown]
# - Dates (monthly)
#
# - Organic Visits (monthly)
# - Non-Organic Visits (monthly)
#
# ***
#
# - Top Landing Pages (for the specified period)
# - Pageviews
# - Avg. Session Durations
# - Bounce Rates

# %%
x = np.linspace(-100,100,1000)
y = (x**2).max() - x**2 + 200*np.random.normal(-1,1,1000)
z = (x**2) + 200*np.random.normal(-1,1,1000)

# %%
plt.plot(x,y)
plt.plot(x,z)

# %% [markdown]
# ## Dates

# %%
dates = np.arange(np.datetime64('2019-01'), np.datetime64('2022-01'))
np.savetxt('data/dates.txt', dates, fmt='%s')

# %% [markdown]
# ## Website Traffic
#
# - ***y*** will be Organic Traffic
# - ***z*** Non-Organic Traffic

# %%
x = np.linspace(100,5000,1000, dtype='int')
plt.plot(x)

# %%
y = ((x**2) + x**2 + 50*np.random.normal(100,1000,1000)).astype(int)
# z = 1/(1 + np.exp(-x)) 
plt.plot(x,y)
# plt.plot(x,z)

# %% [markdown]
# Trying to get y and z on the same plot, where y (organic) grows exponentially and z (all other) has a sigmoid distribution - also at a higher range.

# %%
x = np.linspace(-10, 10, 100) 
z = 1/(1 + np.exp(-x))   
plt.plot(x, z)

# %% [markdown]
# ## Landing Pages

# %% [markdown]
# ## Pageviews, Avg. Session Duration and Bounce Rates

# %%
x = np.linspace(50,9000,10000)
# y = (x**2).max() - x**2 + 200*np.random.normal(-1,1,1000)
# z = (x**2) + 200*np.random.normal(-1,1,1000)

# %%
pageviews = x + 400*np.random.normal(-1,1,10000)
plt.plot(pageviews)

# %%
x = np.linspace(35,5000,10000)
sesh_durations = (x**2).max() - x**2 + 200*np.random.normal(-1,1,10000)

# %%
plt.plot(sesh_durations)

# %%
x = np.linspace(0,100,10000)
bounce = (x**2) + 200*np.random.normal(-1,1,10000)
plt.plot(bounce)
